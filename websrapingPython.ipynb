# %%
# import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url= 'https://mededits.com/medical-school-admissions/statistics/'
page= requests.get(url)
soup= BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]--><!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]--><!--[if gt IE 8]><!--><html lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans%3A400%2C600%2C700%7CRoboto%3A400%2C500%2C700&amp;display=swap" id="ao_optimized_gfonts" media="print" onload="this.onload=null;this.media='all';" rel="stylesheet"/><link href="https://mededits.com/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <!-- Google Tag Manager for WordPress by gtm4wp.com -->
# <script data-cfasync="false" data-pagespeed-no-defer="">
# 	var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
# 	const gtm4wp_use_sku_instead = false;
# 	const gtm4wp_id_prefix = '';
# ...

# %%
soup.find('table', class_ = 'tablepress tablepress-id-21')
# soup.find_all('table')[0]
# Out:
# <table class="tablepress tablepress-id-21" id="tablepress-21">
# <thead>
# <tr class="row-1 odd">
# <th class="column-1">School</th><th class="column-2">State</th><th class="column-3">Average GPA</th><th class="column-4">Average MCAT</th><th class="column-5">Degree</th>
# </tr>
# </thead>
# <tbody class="row-hover">
# <tr class="row-2 even">
# <td class="column-1">A.T. Still University</td><td class="column-2">AZ</td><td class="column-3">3.45</td><td class="column-4">505</td><td class="column-5">DO</td>
# </tr>
# <tr class="row-3 odd">
# <td class="column-1">A.T. Still University of Health Sciences Kirksville College of Osteopathic Medicine</td><td class="column-2">MO</td><td class="column-3">3.69</td><td class="column-4">504</td><td class="column-5">DO</td>
# </tr>
# <tr class="row-4 even">
# <td class="column-1">Alabama College of Osteopathic Medicine</td><td class="column-2">AL</td><td class="column-3">3.45</td><td class="column-4">504</td><td class="column-5">DO</td>
# </tr>
# ...

# %%
#after specifying the table asign it to a variable called table
# table= soup.find_all('table')[0]
table= soup.find('table', class_ = 'tablepress tablepress-id-21')

# %%
row_score_title= table.find_all('th')
row_score_title
# Out:
# [<th class="column-1">School</th>,
#  <th class="column-2">State</th>,
#  <th class="column-3">Average GPA</th>,
#  <th class="column-4">Average MCAT</th>,
#  <th class="column-5">Degree</th>]

# %%
#get the first row with table head
raw_score_title= table.find_all('th')
score_title= [title.text.strip() for title in raw_score_title]
print(score_title)
# Out:
# ['School', 'State', 'Average GPA', 'Average MCAT', 'Degree']

# %%
# we now add data to table titles below and create a csv filr
import pandas as pd

# %%
df= pd.DataFrame(columns=score_title)
df
# Out:
# Empty DataFrame
# Columns: [School, State, Average GPA, Average MCAT, Degree]
# Index: []

# %%
column_data= table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data= row.find_all('td')
    each_raw_data= [data.text.strip() for data in row_data]
  
#     length= len(df)
#     df.loc[length]=each_raw_data
#     print(df)

# %%
df = pd.concat([each_raw_data,df],ignore_index=True)
# df = pd.concat([pd.DataFrame([[1,2,3,4,5,6]],columns=df.columns),df],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = pd.concat([each_raw_data,df],ignore_index=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# ...

# %%
# import pandas as pd
# df = df.append(pd.row_data([[each_raw_data]],columns=df.columns),ignore_index=True)
# df.index = (df.index + 1) % len(df)
# df = df.sort_index()
df = df.append(pd,columns=df.columns),ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3396/793371614.py in ?()
#       1 import pandas as pd
# ----> 2 df = df.append(pd.row_data([[each_raw_data]],columns=df.columns),ignore_index=True)
#       3 df.index = (df.index + 1) % len(df)
#       4 df = df.sort_index()
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 for data in each_raw_data:
# ----> 2     df = pd.DataFrame(each_raw_data , columns=['School', 'State', 'Average GPA', 'Average MCAT', 'Degree'])
#       4 print(df)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:798, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     790         mgr = arrays_to_mgr(
#     791             arrays,
#     792             columns,
#    (...)
#     795             typ=manager,
#     796         )
#     797     else:
# --> 798         mgr = ndarray_to_mgr(
#     799             data,
#     800             index,
#     801             columns,
#     802             dtype=dtype,
#     803             copy=copy,
#     804             typ=manager,
#     805         )
#     806 else:
#     807     mgr = dict_to_mgr(
#     808         {},
# ...

# %%
df = pd.DataFrame([df, each_raw_data],  columns =  ['School', 'State', 'Average GPA', 'Average MCAT', 'Degree']
)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.DataFrame([df, each_raw_data],  columns =  ['School', 'State', 'Average GPA', 'Average MCAT', 'Degree']
#       2 )
#       3 df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:798, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     790         mgr = arrays_to_mgr(
#     791             arrays,
#     792             columns,
#    (...)
#     795             typ=manager,
#     796         )
#     797     else:
# --> 798         mgr = ndarray_to_mgr(
#     799             data,
#     800             index,
#     801             columns,
#     802             dtype=dtype,
#     803             copy=copy,
#     804             typ=manager,
#     805         )
#     806 else:
#     807     mgr = dict_to_mgr(
#     808         {},
#     809         index,
# ...
